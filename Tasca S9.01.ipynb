# %% [markdown]
# 1. Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades. Pots obtenir més informació del seu càlcul en: 🔗 Índice de masa corporal IMC que es y como se calcula.
#
# La funció ha de classificar el resultat en les seves respectives categories.
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduïdes per l’usuari/a no estan en el format adequat o no pren valors raonables.

# %%
def clasificación_imc():
    try:
        # solicitamos los datos al usuario
        peso = float(input('Ingrese su peso en kg: '))
        altura = float(input('Introduce tu altura en m: '))

        # validación de los datos introducidos
        if peso <= 0 or peso >= 300:
            raise ValueError('Error el peso tiene que ser positivo e inferior a 300 kg. ')
            
        if altura <= 0 or altura >= 2.5:
            raise ValueError('Error la altura tiene que ser positiva e inferior a 2.5m ')
            

        # Calculamos el IMC
        imc = peso / (altura**2)

        # clasificacion segun el IMC
        if imc < 18.5:
            print(f"Tu IMC es {round(imc, 2)}, Categoría: Bajo peso")
        elif 18.5 <= imc < 24.9:
            print(f"Tu IMC es {round(imc, 2)}, Categoría: Peso normal")
        elif 25 <= imc < 29.9:
            print(f"Tu IMC es {round(imc, 2)}, Categoría: Sobrepeso")
        else:
            print(f"Tu IMC es {round(imc, 2)}, Categoría: Obesidad")

    except ValueError as ValorError:
        print("Por favor, ingrese valores numéricos válidos para el peso y la altura.\n", ValorError)

# %%
# Ejecutar la función

clasificación_imc()
# Out:
# Tu IMC es 23.51, Categoría: Peso normal

# %% [markdown]
# 2. Convertidor de temperatures
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re).
#
# Selecciona almenys 2 conversors, de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions, de manera que es puguin guardar (recorda que un print() no es pot guardar mai).
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduides per l’usuari/a no estan en el format adequat.
#
# (EXTRA): Pensa una manera d’emmagatzemar totes les possibles conversions en un sol objecte (Llista? Diccionari? DataFrame?) en comptes d’escriure molts if else en funció de la temperatura d’origen i la temperatura de destí.

# %%
# Definimos la función
def convertir_temperatura():
    try:
        valor = float(input('Introduce el valor de la temperatura: '))
        unidad_origen = input('Introduce la unidad (C, F, K): ').strip().upper()

        # Validación unidad de origen
        if unidad_origen not in ['C', 'F', 'K']:
            raise ValueError('Unidad de origen no existente. Utiliza C, F, K. ')

        # Creamos un nuevo diccionario para guardar las conversiones 
        conversiones_temp = {}

        # conversión desde Celsius 
        if unidad_origen == 'C':
            conversiones_temp['Celsius'] = valor
            conversiones_temp['Fahrenheit'] = (valor * 9/5) + 32
            conversiones_temp['Kelvin'] = valor + 273.15
            conversiones_temp['Rankine'] = (valor + 273.15) * 9/5
            conversiones_temp['Réaumur'] = valor * 0.8

        # conversión desde Fahrenheit
        elif unidad_origen == 'F':
            celsius = (valor - 32) * 5/9
            conversiones_temp['Celsius'] = celsius
            conversiones_temp['Fahrenheit'] = valor
            conversiones_temp['Kelvin'] = celsius + 273.15
            conversiones_temp['Rankine'] = valor + 459.67
            conversiones_temp['Réaumur'] = celsius * 0.8

        # conversión desde Kelvin
        elif unidad_origen == 'K':
            celsius = valor - 273.15
            conversiones_temp['Celsius'] = celsius
            conversiones_temp['Fahrenheit'] = (celsius * 9/5) + 32
            conversiones_temp['Kelvin'] = valor
            conversiones_temp['Rankine'] = valor * 1.8
            conversiones_temp['Réaumur'] = celsius * 0.8

        # mostrar los resultados

        print("\nConversión actual:")
        for unidad, resultado in conversiones_temp.items():
            print(f"{unidad}: {round(resultado, 2)}")
        
        for unidad in conversiones_temp:
            conversiones_temp[unidad] = round(conversiones_temp[unidad], 2)
        print(conversiones_temp)

    except ValueError as valorError:
        print('Ingrese valor numérico o unidad correcta.\n', valorError)

# %%
# Llamar a la función
convertir_temperatura()
# Out:
# Conversión actual:
# Celsius: -1.11
# Fahrenheit: 30.0
# Kelvin: 272.04
# Rankine: 489.67
# Réaumur: -0.89
# {'Celsius': -1.11, 'Fahrenheit': 30.0, 'Kelvin': 272.04, 'Rankine': 489.67, 'Réaumur': -0.89}

# %% [markdown]
# 3. Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula. Intenta que es gestionin totes les casuístiques possibles que facin que el programa no funcioni correctament.
#
# (EXTRA): Quina és la llargada mitjana de les paraules del text que has escrit? “Hola com va?” hauria de retornar (4+3+2) / 3 = 3

# %%
import string
def contador_palabras():
    try:
        texto = input('introduce un texto: ')
        
        # validacion de texto 
        if not texto.split():
            raise ValueError('Introduce un texto que no este vacio')
        
        # pasar todo el texto a minusculas
        texto = texto.lower()

        # Eliminación de todos los signos estandar
        traductor = str.maketrans('', '', string.punctuation)
        texto = texto.translate(traductor)

        # separación de las palabras
        palabras = texto.split()

        # Validación de palabras en el texto
        if not palabras:
            raise ValueError ('No hay palabras en el texto: vuelve a escribirlo')
        
        # Realizamos el conteo de las palabras creando un diccionario
        contador = {}
        for p in palabras:
            if p in contador:
                contador[p]  += 1 
            else:
                contador[p] = 1
        
        # Calculo de la longitud y longitud media de las palabras
        longitud = [len(p) for p in palabras]
        longitud_media = sum(longitud) / len(longitud)

        # Mostrar los resultados 
        print('\nConteo de palabras:')
        for palabra, cantidad in contador.items():
            print(f'{palabra} : {cantidad} ')
        
        print(f'\nNumero total de palabras : {len(palabras)}')
        print(f'Longitud media de las palabras : {round(longitud_media, 2)}')
    
    except ValueError as valorError:
        print('Ingrese un texto con palabras.\n', valorError)

# %%
# llamamos a la función
contador_palabras()
# Out:
# Conteo de palabras:
# tu : 2
# perro : 4
# es : 1
# muy : 1
# bonito : 1
# pero : 1
# el : 2
# de : 2
# juan : 2
# tambien : 1
# y : 1
# tiene : 2
# una : 1
# sonrisa : 1
# que : 1
# no : 1
#
# Numero total de palabras : 24
# Longitud media de las palabras : 3.67

# %% [markdown]
# 4. Diccionari invers (amb possibilitat de duplicats)
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviant les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment, juntament amb una llista amb els valors associats a la clau repetida.
#
# Fixa’t en el següents exemples per veure l’output esperat.

# %%
# creamos un diccionario
paises_idioma = {
    "España": "Español",
    "México": "Español",
    "Argentina": "Español",
    "Francia": "Francés",
    "Bélgica": "Francés",
    "Italia": "Italiano",
    "Brasil": "Portugués",
    "Portugal": "Portugués",
    "Alemania": "Alemán",
}

dni_nombre = {
    12345: 'Daniel',
    13456: 'Juan',
    12356: 'Esteban',
    13567: 'Roberto',
    13457: 'Daniel',
    14356: 'Ana',
    15346: 'Sandra',
    12567: 'Ana',
    14235: 'Daniel',

}

def diccionario_invertido(diccionario):

    # creamos el diccionario invertido
    valor_clave = {}
    for clave, valor in diccionario.items():
        if valor in valor_clave:
            valor_clave[valor].append(clave)
        else:
            valor_clave[valor] = [clave]
    
    # Buscamos si hay valores repetidos 
    
    repetidos = {valor: clave for valor, clave in valor_clave.items() if len (clave) > 1}

    if repetidos:
        print('Hay valores repetidos!!!\n')
        for valor, clave in repetidos.items():
            print(f'El valor {valor} esta asociado a la clave : {clave}\n')
    
    print('diccionario invertido\n')
    print(valor_clave)

# %%
# Ejecutamos la función

diccionario_invertido(dni_nombre)
# Out:
# Hay valores repetidos!!!
#
# El valor Daniel esta asociado a la clave : [12345, 13457, 14235]
#
# El valor Ana esta asociado a la clave : [14356, 12567]
#
# diccionario invertido
#
# {'Daniel': [12345, 13457, 14235], 'Juan': [13456], 'Esteban': [12356], 'Roberto': [13567], 'Ana': [14356, 12567], 'Sandra': [15346]}

# %% [markdown]
# Nivell 2
# 1. Comptador i endreçador de paraules d'un text.
#
# El client va quedar content amb el comptador de paraules, però ara vol llegir arxius TXT i que calculi la freqüència de cada paraula ordenades dins de les entrades habituals del diccionari segons la lletra amb la qual comencen, és a dir, les claus han d'anar de la A a la Z i dins de la A hem d'anar de la A la Z. Per exemple, per a l'arxiu "tu_me_quieres_blanca.txt" la sortida esperada seria:

# %%
import string
from pprint import pprint

# Definimos la función
def contador_palabras_txt(file_path):
    try:
        #  Abrir y leer el archivo TXT
        with open(file_path, "r", encoding="utf-8") as f:
            texto = f.read()

        #  Validación de archivo o texto vacio
        if not texto.strip():
            raise ValueError("El archivo está vacío. Introduce un texto válido.")

        # Pasar todo el archivo a minúsculas
        texto = texto.lower()

        # Eliminación de todos los signos estandar
        traductor = str.maketrans('', '', string.punctuation)
        texto = texto.translate(traductor)

        # Separar las palabras
        palabras = texto.split()

        if not palabras:
            raise ValueError("No se encontraron palabras válidas en el archivo.")

        # Crear diccionario  A-Z
        diccionario_final = {letra: {} for letra in string.ascii_lowercase}

        # Variable para calcular la media de longitud del archivo
        total_letras = 0

        # Recorrer cada palabra y contar frecuencia
        for palabra in palabras:
            primera_letra = palabra[0]

            # Si la palabra empieza con un carácter no alfabético, la saltamos
            if primera_letra not in diccionario_final:
                continue
            diccionario_final[primera_letra][palabra] = diccionario_final[primera_letra].get(palabra, 0) + 1
            total_letras += len(palabra)

        # Ordenar letras y palabras internamente
        diccionario_final = dict(sorted(diccionario_final.items()))
        diccionario_final = {k: dict(sorted(v.items())) for k, v in diccionario_final.items()}

        # Imprimir resultado como diccionario
        pprint(diccionario_final)


        # Calcular media de longitud de palabras
        media_longitud = total_letras / len(palabras)
        print(f"\nNúmero total de palabras: {len(palabras)}")
        print(f"Longitud media de las palabras: {round(media_longitud, 1)}")

    except FileNotFoundError:
        print(" Error: No se encontró el archivo. Verifica la ruta.")

# %%
contador_palabras_txt("C:/Users/nuez_/Downloads/tu me quieres blanca.txt")
# Out:
# {'a': {'a': 3,
#        'agua': 1,
#        'al': 2,
#        'alba': 4,
#        'alcobas': 1,
#        'alimenta': 1,
#        'alma': 1,
#        'amarga': 1,
#        'azucena': 1},
#  'b': {'baco': 1,
#        'banquete': 1,
#        'bebe': 1,
#        'blanca': 3,
#        'boca': 1,
#        'bosques': 1,
#        'buen': 1},
#  'c': {'cabañas': 1,
#        'carnes': 2,
#        'casta': 3,
#        'cerrada': 1,
#        'con': 4,
#        'conservas': 1,
#        'copas': 1,
#        'corola': 1,
#        'corriste': 1,
#        'cuando': 2,
#        'cubierto': 1,
#        'cuerpo': 1,
#        'cuáles': 1},
#  'd': {'de': 8, 'dejaste': 1, 'del': 1, 'diga': 1, 'dios': 2, 'duerme': 1},
#  'e': {'el': 4,
#        'ellas': 1,
#        'en': 4,
#        'engaño': 1,
#        'enredada': 1,
#        'entonces': 1,
#        'escarcha': 1,
#        'espumas': 1,
#        'esqueleto': 1,
#        'estrago': 1},
#  'f': {'festejando': 1, 'filtrado': 1, 'frutos': 1},
#  'g': {},
# ...

# %% [markdown]
# 2. Conversió de tipus de dades.
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir. Exemple de la llista que rep el client:

# %%
lista_cliente = [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]

def separar_flotantes(lista):
    lista_float = []
    lista_no_float =[]

    for elem in lista:
        if isinstance (elem,(list, tuple)):
            conv, no_conv = separar_flotantes(elem)
            lista_float.extend(conv)
            lista_no_float.extend(no_conv)

        else:
            try:
                lista_float.append(float(elem))
            except (ValueError, TypeError):
                lista_no_float.append(elem)

    return lista_float, lista_no_float

# %%
separar_flotantes(lista_cliente)
# Out:
# ([1.3, 10000000000.0, 2.0, 1.0, 1.4, 1.0, 2.0, 3.0, 3.4],
#  ['one', 'seven', '3-1/2', 'not-a-number'])

# %% [markdown]
# Nivell 3
# 1. Generador de Contrasenyes
#
# Explora el funcionament del mòdul random de la llibreria numpy. 🔗 Random module in NumPy
#
# En aquest punt, el client ha detectat un problema amb les contrasenyes que utilitzen els seus treballadors. Asdf1234, dates d’aniversari o similars. Per a solucionar-ho ens ha encarregat una funció de Python que generi contrasenyes més segures. La funció ha de dependre dels següents paràmetres:
#
# longitud (int): Longitud de la contrasenya
# majuscules (bool = True): Si hi ha d’aparèixer majúscules
# minuscules (bool = True): Si hi ha d’aparèixer minúscules
# numeros (bool = True): Si hi ha d’aparèixer números
# signes (bool = False): Si hi ha d’aparèixer caràcters especials (,-$? o similars)
# Així doncs, si executem la funció de la següent manera:
#
# crear_contrasenya(10, True, True, True, True)
#
# Hauríem d’obtenir un output (que hem de poder guardar) de l’estil:
#
# 9Er,5Vn8P$
#
# Assegura’t que es compleixin tots els criteris, i que aquestes contrasenyes siguin realment aleatòries.
#
# (EXTRA) Explora com podríem fer que la funció copiés la contrasenya automàticament al porta papers de l’ordinador (com si l’haguéssim seleccionat i fet ctrl+copy).

# %%
import string
import numpy as np
import random
import pyperclip

# definimos la función y el tipo de caracteres que vamos a usar
def crear_contraseña(longitud=10, mayusculas=True, minusculas=True, numeros=True, signos=False):
    caracteres = ""
    if mayusculas:
        caracteres += string.ascii_uppercase
    if minusculas:
        caracteres += string.ascii_lowercase
    if numeros:
        caracteres+= string.digits
    if signos:
        caracteres += string.punctuation

    if not caracteres:
        return "Debe seleccionar al menos un tipo de carácter"
    
    # Generamos la contraseña 

    contraseña = ''.join(random.choices(caracteres, k=longitud))

    # Copiar la contraseña al portapapeles
    pyperclip.copy(contraseña)
    return(contraseña)

# %%
crear_contraseña(10, True, True, True, True)
# Out:
# '@qh/e1l76d'

# %% [markdown]
# 2. Processament de dades simple
#
# Una companya de feina ens ha demanat un favor, aprofitant que sap que estem aprenent a programar. Té un històric de partits de futbol català en un fitxer, on hi ha emmagatzemat els noms dels equips i els resultats. Necessita que processem les dades de manera automàtica, per extreure’n els resultats que necessita.
#
# Utilitza el fitxer "historic_partits.txt"
#
# Necessita un programa que retorni:
#
# El nombre total de gols que ha fet cada equip.
# El nom de l’equip més golejador.
# El nom de l’equip més golejat
# La classificació global (cada victòria: 3 pts, empat 1 pts, derrota 0 pts)
# Com a referència, els equips amb més punts serien els següents:
#
# imatge resultat partits
# Pots utilitzar el format que et sigui més convenient.

# %%
# definimos la función
def analisis_resultados_txt(file_path):
    goles_hechos = {}
    goles_recibidos = {} 
    puntos = {}

    with open(file_path, 'r', encoding='utf-8') as archivo:
        for linea in archivo:
            partes = linea.strip().split('\t')
            if len(partes) != 3:
                continue
        
            equipo_local, resultado, equipo_visitante = partes
            try:
                goles_local, goles_visitante = map(int, resultado.split('-'))
            except ValueError:
                continue

            # Goles hechos
            goles_hechos[equipo_local] = goles_hechos.get(equipo_local, 0) + goles_local
            goles_hechos[equipo_visitante] = goles_hechos.get(equipo_visitante, 0) + goles_visitante

            # Goles recibidos
            goles_recibidos[equipo_local] = goles_recibidos.get(equipo_local, 0) + goles_visitante
            goles_recibidos[equipo_visitante] = goles_recibidos.get(equipo_visitante, 0) + goles_local

            # Inicializamos los puntos
            if equipo_local not in puntos:
                puntos[equipo_local] = 0
            if equipo_visitante not in puntos:
                puntos[equipo_visitante] = 0

            # Clasificación por puntos
            if goles_local > goles_visitante:
                puntos[equipo_local] += 3
            elif goles_local < goles_visitante:
                puntos[equipo_visitante] += 3 
            else:
                puntos[equipo_local] += 1
                puntos[equipo_visitante] += 1
    
    equipo_goleador = max(goles_hechos.items(), key=lambda x: x[1])
    equipo_goleado = max(goles_recibidos.items(), key=lambda x: x[1])

    return goles_hechos, equipo_goleador, equipo_goleado, puntos

# %%
goles_por_equipo, goleador, goleado, clasificacion = analisis_resultados_txt(r"C:\Users\nuez_\Desktop\BOOTCAMP DATA\historic partits.txt")

print("Goles marcados por cada equipo:")
for equipo, goles in sorted(goles_por_equipo.items(), key=lambda x: x[1], reverse=True):
    print(f"{equipo}: {goles} goles")

print(f"\nEquipo más goleador: {goleador[0]} con {goleador[1]} goles")
print(f"Equipo más goleado: {goleado[0]} con {goleado[1]} goles recibidos")
# Out:
# Goles marcados por cada equipo:
# Figueres: 161 goles
# Llagostera: 159 goles
# Vilafranca: 157 goles
# Terrassa: 147 goles
# Cornellà: 147 goles
# Sabadell: 141 goles
# Girona FC: 139 goles
# Badalona: 134 goles
# Olot: 132 goles
# RCD Espanyol: 131 goles
# Nàstic de Tarragona: 130 goles
# Lleida Esportiu: 129 goles
# FC Barcelona: 125 goles
# Sant Andreu: 123 goles
# Granollers: 122 goles
# Reus Deportiu: 119 goles
# Cerdanyola: 117 goles
# Manlleu: 106 goles
# Prat: 106 goles
# Europa: 93 goles
#
# Equipo más goleador: Figueres con 161 goles
# Equipo más goleado: Vilafranca con 172 goles recibidos

# %%
goles_por_equipo, goleador, goleado, clasificacion = analisis_resultados_txt(r"C:\Users\nuez_\Desktop\BOOTCAMP DATA\historic partits.txt")

print("\nClasificación por puntos:")
for equipo, puntos in sorted(clasificacion.items(), key=lambda x: x[1], reverse=True):
    print(f"{equipo}: {puntos} puntos")
# Out:
# Clasificación por puntos:
# Girona FC: 96 puntos
# Llagostera: 94 puntos
# Sabadell: 85 puntos
# Cornellà: 82 puntos
# RCD Espanyol: 80 puntos
# Figueres: 79 puntos
# Lleida Esportiu: 75 puntos
# Terrassa: 74 puntos
# FC Barcelona: 73 puntos
# Vilafranca: 72 puntos
# Badalona: 68 puntos
# Reus Deportiu: 68 puntos
# Nàstic de Tarragona: 68 puntos
# Granollers: 67 puntos
# Olot: 64 puntos
# Sant Andreu: 62 puntos
# Manlleu: 57 puntos
# Prat: 56 puntos
# Cerdanyola: 56 puntos
# Europa: 41 puntos
